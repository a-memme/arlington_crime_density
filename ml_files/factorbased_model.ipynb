# %%
import pandas as pd
import statsmodels.api as sm
import seaborn as sns
import matplotlib.pyplot as plt

# %%
state_df = pd.read_csv("FBIState.txt")
census_df = pd.read_csv("census_data.csv")
county_df = pd.read_csv("ARLCrime.txt",encoding='utf-8')

# %%
# Create df for demographic regression by zip, year, type
county_df = county_df[(county_df['category'] != 0) & (county_df['category'] != 4)]
county_byZipYearType = county_df.groupby(['zip','IncidentYear','IncidentMonth','category']).size().reset_index(name='count')
state_byZipYearType = state_df.groupby(['zip','IncidentYear','category']).size().reset_index(name='state_count')
df = pd.merge(county_byZipYearType, census_df, left_on=['zip', 'IncidentYear'], right_on=['zip','year'])
df = pd.merge(df, state_byZipYearType, on=['zip','IncidentYear','category'])
df = pd.get_dummies(df, columns=['category','zip'])
X = df.drop(columns=['state_count','IncidentYear','IncidentMonth'])  # Independent variables
y = df['state_count']  # Dependent variable
X = X.astype(float)
y = y.astype(float)
X = sm.add_constant(X)  # Add a constant for the intercept term
model = sm.OLS(y, X).fit()  # Fit the regression model
print(model.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            state_count   R-squared:                       0.851
# Model:                            OLS   Adj. R-squared:                  0.849
# Method:                 Least Squares   F-statistic:                     457.9
# Date:                Thu, 18 Apr 2024   Prob (F-statistic):               0.00
# Time:                        20:11:09   Log-Likelihood:                -9955.5
# No. Observations:                1627   AIC:                         1.995e+04
# Df Residuals:                    1606   BIC:                         2.007e+04
# Df Model:                          20
# Covariance Type:            nonrobust
# ======================================================================================
#                          coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# const                3.67e+04   4861.188      7.549      0.000    2.72e+04    4.62e+04
# count                  5.4670      0.250     21.869      0.000       4.977       5.957
# year                 -26.0128      3.445     -7.550      0.000     -32.771     -19.255
# HS                    -0.5023      3.551     -0.141      0.888      -7.468       6.463
# Bachelors             -0.5023      3.551     -0.141      0.888      -7.468       6.463
# Masters              -12.3639     15.103     -0.819      0.413     -41.988      17.260
# Doctorate            -15.1394      7.105     -2.131      0.033     -29.075      -1.203
# PovertyRate            7.1155      3.983      1.786      0.074      -0.698      14.929
# Households_lt_10k    -39.7997      7.501     -5.306      0.000     -54.512     -25.088
# Households_mt_200k    -2.4948      4.586     -0.544      0.586     -11.489       6.500
# Black                 -5.5826      6.457     -0.865      0.387     -18.248       7.083
# Latino                -9.3816      4.431     -2.117      0.034     -18.072      -0.691
# White                  5.1888      4.027      1.289      0.198      -2.709      13.087
# category_1          1.208e+04   1620.680      7.456      0.000    8905.103    1.53e+04
# category_2          1.241e+04   1619.589      7.660      0.000    9229.456    1.56e+04
# category_3          1.221e+04   1620.941      7.532      0.000    9029.494    1.54e+04
# zip_22201           4789.8385    614.638      7.793      0.000    3584.262    5995.415
# zip_22202           4776.9042    607.053      7.869      0.000    3586.205    5967.604
# zip_22203           4550.5114    611.167      7.446      0.000    3351.743    5749.280
# zip_22204           4580.1452    580.492      7.890      0.000    3441.544    5718.746
# zip_22205           4487.0543    618.024      7.260      0.000    3274.837    5699.272
# zip_22206           4493.9427    608.406      7.386      0.000    3300.589    5687.297
# zip_22207           4578.1112    620.223      7.381      0.000    3361.579    5794.643
# zip_22209           4442.5279    610.551      7.276      0.000    3244.968    5640.088
# ==============================================================================
# Omnibus:                      246.578   Durbin-Watson:                   0.318
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              500.741
# Skew:                           0.902   Prob(JB):                    1.84e-109
# Kurtosis:                       5.032   Cond. No.                     1.24e+19
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 4.32e-29. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.

# %%
county_df = county_df[(county_df['category'] != 0) & (county_df['category'] != 4)]
county_byZipYearType = county_df.groupby(['zip','IncidentYear','IncidentMonth','category']).size().reset_index(name='count')
state_byZipYearType = state_df.groupby(['zip','IncidentYear','category']).size().reset_index(name='state_count')
df = pd.merge(county_byZipYearType, state_byZipYearType, on=['zip','IncidentYear','category'])
df = pd.get_dummies(df, columns=['category','zip'])
X = df.drop(columns=['state_count','IncidentYear','IncidentMonth'])  # Independent variables
y = df['state_count']  # Dependent variable
X = X.astype(float)
y = y.astype(float)
X = sm.add_constant(X)  # Add a constant for the intercept term
model = sm.OLS(y, X).fit()  # Fit the regression model
print(model.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            state_count   R-squared:                       0.747
# Model:                            OLS   Adj. R-squared:                  0.745
# Method:                 Least Squares   F-statistic:                     560.5
# Date:                Thu, 18 Apr 2024   Prob (F-statistic):               0.00
# Time:                        20:11:20   Log-Likelihood:                -12145.
# No. Observations:                1911   AIC:                         2.431e+04
# Df Residuals:                    1900   BIC:                         2.437e+04
# Df Model:                          10
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        202.2897      3.126     64.710      0.000     196.159     208.421
# count          0.9115      0.221      4.121      0.000       0.478       1.345
# category_1   -92.2132      4.631    -19.910      0.000    -101.297     -83.130
# category_2   300.0071      6.718     44.654      0.000     286.831     313.183
# category_3    -5.5042      5.080     -1.083      0.279     -15.468       4.459
# zip_22201    223.0941      8.461     26.367      0.000     206.500     239.688
# zip_22202    223.1926      8.868     25.167      0.000     205.800     240.586
# zip_22203    -30.9267      8.313     -3.720      0.000     -47.230     -14.624
# zip_22204    200.1223      8.449     23.685      0.000     183.551     216.693
# zip_22205   -148.9175      9.078    -16.405      0.000    -166.721    -131.114
# zip_22206    -87.6353      8.509    -10.299      0.000    -104.323     -70.948
# zip_22207    -61.4895      8.678     -7.086      0.000     -78.508     -44.471
# zip_22209   -115.1503      8.673    -13.277      0.000    -132.160     -98.141
# ==============================================================================
# Omnibus:                      313.225   Durbin-Watson:                   0.167
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              931.162
# Skew:                           0.840   Prob(JB):                    6.32e-203
# Kurtosis:                       5.978   Cond. No.                     6.62e+17
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 3.01e-30. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.

# %%
# Create df for demographic regression by zip, year, type - dummies by category
county_byZipYearType = county_df.groupby(['zip','IncidentYear','IncidentMonth','category']).size().reset_index(name='count')
df = pd.merge(county_byZipYearType, census_df, left_on=['zip', 'IncidentYear'], right_on=['zip','year'])

X = df.drop(columns=['count'])  # Independent variables
y = df['count']  # Dependent variable
X = X.astype(float)
y = y.astype(float)
X = sm.add_constant(X)  # Add a constant for the intercept term
model = sm.OLS(y, X).fit()  # Fit the regression model
print(model.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  count   R-squared:                       0.582
# Model:                            OLS   Adj. R-squared:                  0.578
# Method:                 Least Squares   F-statistic:                     147.4
# Date:                Thu, 18 Apr 2024   Prob (F-statistic):          3.64e-306
# Time:                        19:43:08   Log-Likelihood:                -6523.2
# No. Observations:                1708   AIC:                         1.308e+04
# Df Residuals:                    1691   BIC:                         1.317e+04
# Df Model:                          16
# Covariance Type:            nonrobust
# ======================================================================================
#                          coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# const               2.943e+04   2367.028     12.432      0.000    2.48e+04    3.41e+04
# zip                   -1.7746      0.124    -14.312      0.000      -2.018      -1.531
# IncidentYear           1.0176      0.145      7.025      0.000       0.734       1.302
# IncidentMonth          0.2390      0.078      3.082      0.002       0.087       0.391
# year                   1.0176      0.145      7.025      0.000       0.734       1.302
# HS                     0.2096      0.136      1.541      0.123      -0.057       0.476
# Bachelors              0.2096      0.136      1.541      0.123      -0.057       0.476
# Masters               -1.4234      1.277     -1.114      0.265      -3.929       1.082
# Doctorate             -1.9658      0.516     -3.808      0.000      -2.978      -0.953
# PovertyRate            1.9848      0.363      5.473      0.000       1.274       2.696
# Households_lt_10k     -0.6844      0.422     -1.620      0.105      -1.513       0.144
# Households_mt_200k    -1.3623      0.391     -3.483      0.001      -2.129      -0.595
# Black                  0.5399      0.189      2.862      0.004       0.170       0.910
# Latino                -0.1596      0.156     -1.024      0.306      -0.465       0.146
# White                 -0.4483      0.197     -2.270      0.023      -0.835      -0.061
# category_0          5873.2616    473.193     12.412      0.000    4945.156    6801.367
# category_1          5886.0067    473.495     12.431      0.000    4957.309    6814.705
# category_2          5908.0660    473.500     12.477      0.000    4979.357    6836.775
# category_3          5882.0730    473.491     12.423      0.000    4953.384    6810.762
# category_4          5877.4610    473.455     12.414      0.000    4948.841    6806.081
# ==============================================================================
# Omnibus:                      704.694   Durbin-Watson:                   2.145
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             4263.718
# Skew:                           1.831   Prob(JB):                         0.00
# Kurtosis:                       9.819   Cond. No.                     2.48e+20
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 1.39e-29. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
